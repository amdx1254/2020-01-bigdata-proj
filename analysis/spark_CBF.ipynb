# %%
import findspark
import pandas as pd
import numpy as np
import csv
findspark.init('/home/hadoop/spark-2.2.2-bin-hadoop2.7')

from pyspark.sql import SQLContext
from pyspark import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.sql.types import *

sc = SparkContext()
spark = SparkSession(sc)
sqlContext = SQLContext(sc)

# %%
def define_structure(string, format_type):
    try: typo = equivalent_type(format_type)
    except: typo = StringType()
    return StructField(string, typo)

def pandas_to_spark(pandas_df):
    columns = list(pandas_df.columns)
    types = list(pandas_df.dtypes)
    struct_list = []
    for column, typo in zip(columns, types): 
      struct_list.append(define_structure(column, typo))
    p_schema = StructType(struct_list)
    return sqlContext.createDataFrame(pandas_df, p_schema)

pd_df = pd.read_csv('./wadiz_remove_duplicate.csv')
spark_df = pandas_to_spark(pd_df)

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import udf, lit

soop = udf(lambda category, makerName, summary: (category + ' ')*1 + (makerName + ' ')*2 + summary)
spark_df = spark_df.withColumn("id", spark_df['id'].cast('integer'))
spark_df = spark_df.withColumn("achievementRate", spark_df['achievementRate'].cast('integer'))
spark_df = spark_df.withColumn("totalAmount", spark_df['totalAmount'].cast('integer'))
spark_df = spark_df.withColumn("totalSupporter", spark_df['totalSupporter'].cast('integer'))
spark_df = spark_df.withColumn("totalLike", spark_df['totalLike'].cast('integer'))
spark_df = spark_df.withColumn("rewardSatisfaction", spark_df['rewardSatisfaction'].cast('double'))
spark_df = spark_df.withColumn("makerSatisfaction", spark_df['makerSatisfaction'].cast('double'))
spark_df = spark_df.withColumn("soop", soop(spark_df['category'], spark_df['makerName'], spark_df['summary']).cast('string'))
spark_df.printSchema()
# Out:
# root
#  |-- Unnamed: 0: string (nullable = true)
#  |-- Unnamed: 0.1: string (nullable = true)
#  |-- Unnamed: 0.1.1: string (nullable = true)
#  |-- Unnamed: 0.1.1.1: string (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- makerName: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- achievementRate: integer (nullable = true)
#  |-- totalAmount: integer (nullable = true)
#  |-- totalSupporter: integer (nullable = true)
#  |-- totalLike: integer (nullable = true)
#  |-- rewardSatisfaction: double (nullable = true)
#  |-- makerSatisfaction: double (nullable = true)
#  |-- detailUrl: string (nullable = true)
#  |-- campaigncomments: string (nullable = true)
#  |-- comments: string (nullable = true)
#  |-- soop: string (nullable = true)

# %%
def dividePrice(totalAmount, totalSupporter):
    if totalSupporter == 0:
        return 0
    price = int(totalAmount / totalSupporter)
    if 0 <= price and price <30000:
        return 0
    elif 30000<= price and price <50000:
        return 1
    elif 50000<= price and price <70000:
        return 2
    elif 70000<= price and price <100000:
        return 3
    elif 100000<= price and price <200000:
        return 4
    elif 200000<= price and price< 300000:
        return 5
    elif 300000<= price and price <400000:
        return 6
    elif 400000<= price and price <500000:
        return 7
    else:
        return 8
    
price_udf = udf(dividePrice, IntegerType())
spark_df = spark_df.withColumn('rangeAmount', price_udf(spark_df['totalAmount'], spark_df['totalSupporter']))
spark_df.printSchema()
# Out:
# root
#  |-- Unnamed: 0: string (nullable = true)
#  |-- Unnamed: 0.1: string (nullable = true)
#  |-- Unnamed: 0.1.1: string (nullable = true)
#  |-- Unnamed: 0.1.1.1: string (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- makerName: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- achievementRate: integer (nullable = true)
#  |-- totalAmount: integer (nullable = true)
#  |-- totalSupporter: integer (nullable = true)
#  |-- totalLike: integer (nullable = true)
#  |-- rewardSatisfaction: double (nullable = true)
#  |-- makerSatisfaction: double (nullable = true)
#  |-- detailUrl: string (nullable = true)
#  |-- campaigncomments: string (nullable = true)
#  |-- comments: string (nullable = true)
#  |-- soop: string (nullable = true)
#  |-- rangeAmount: integer (nullable = true)

# %% [markdown]
# ### Text Processing and Featurization

# %%
spark_df.registerTempTable('wadiz')
res= sqlContext.sql('SELECT id, name, summary, category, makerName, rangeAmount, soop from wadiz')
res.show()
# Out:
# +-----+--------------------+--------------------+--------+-------------------+-----------+--------------------+
# |   id|                name|             summary|category|          makerName|rangeAmount|                soop|
# +-----+--------------------+--------------------+--------+-------------------+-----------+--------------------+
# |10038|당신의 공간에 이야기를 불어넣는...|
#     "사람들은 모두 각자 ...|   디자인소품|           with yoo|          3|디자인소품 with yoo wi...|
# |10047|세상을 바꾸는 작은선물 밸리스 ...|
#     본 프로젝트의 수익금 ...|      푸드|                밸리스|          0|푸드 밸리스 밸리스
#     본...|
# |10048|배변자세 교정기 모닝스마일로 변...|
#     배변자세 교정기 "모닝...|   디자인소품|       GFV Co,. Ltd|          0|디자인소품 GFV Co,. Lt...|
# |10052|당신의 취미를 찾아주는 특별한 ...|
#     당신의 취미를 찾아드립...|   디자인소품|               HOBY|          1|디자인소품 HOBY HOBY
# ...|
# |10056|건강한 두뇌를 위한 취미이야기,...|
#     당신은 어떤 운동을 하...|   디자인소품|이에스 스튜디오(ES studio)|          0|디자인소품 이에스 스튜디오(ES...|
# |10090|혼자있어 외로운 반려동물과 당신...|
#     당신과 반려동물의 행복...|    반려동물|            (주)아이오텍|          3|반려동물 (주)아이오텍 (주)아...|
# |10115|화재를 진압할 수 있는 또 하나...|
#     소방담요란 화재가 발생...|   디자인소품|              디자인탐정|          0|디자인소품 디자인탐정 디자인탐정...|
# |10123|집에서 꿀근육 장착! 프리웨이트...|
#     오로지 가성비만 생각....|스포츠·모빌리티|       지창대 (BROFIT)|          4|스포츠·모빌리티 지창대 (BRO...|
# |10136|iPad 와 함께하면 더 좋은 ...|
#     태블릿PC 또는 스마트...|   디자인소품|      Rollory (롤로리)|          3|디자인소품 Rollory (롤로...|
# |10173|16가지 피부 타입별 맞춤형 화...|
#     아무리 비싸도 내 피부...|      뷰티|       (주)엠플러스코스메틱스|          0|뷰티 (주)엠플러스코스메틱스 (...|
# |10178|이어폰 사용자들의  필수 아이템...|
#     지금까지 본 적 없는 ...|   디자인소품|        DESIGN.MADD|          0|디자인소품 DESIGN.MADD...|
# |10330|앤틱한 원목 스피커  '사운드 호른'|
#     오래된 축음기의 형태를...|   디자인소품|              디자인길드|          2|디자인소품 디자인길드 디자인길드...|
# |10379|포근함으로 안아주는 어쿠스틱 밴...|
#     어쿠스틱 감성밴드 Su...|   공연·컬쳐|         선데(Sundae)|          0|공연·컬쳐 선데(Sundae) ...|
# |10408|커피의 눈물이 주는 최고의 선물...|
#     최상의 콜드브루 커피를...|   디자인소품|             (주)제미스|          1|디자인소품 (주)제미스 (주)제...|
# |10416|[한정수량]냥이들이 따끈따끈 식...|
#     고양이가 노릇노릇 익어...|    반려동물|               파운드캣|          0|반려동물 파운드캣 파운드캣
#  ...|
# |10420|숨은 편안함, 디테일한 자신감 ...|
#     100% 이집트순면 소...|   패션·잡화|   위버버드 Weaver Bird|          0|패션·잡화 위버버드 Weaver...|
# |10424|삶을 바꾸는 작은 습관, 알디프...|
#     한 잔의 차에 ‘지금,...|      푸드|         알디프 ALTDIF|          1|푸드 알디프 ALTDIF 알디프...|
# |10439|맑은 날, 추락 및 침입 걱정말...|
#     환기를 하거나 더울 때...|     홈리빙|       제이에이치케이(JHK)|          0|홈리빙 제이에이치케이(JHK) ...|
# |10464|[앵콜] 캄보디아에 학교를 짓는...|
#     캄보디아 빈민가 아이들...|   패션·잡화|          딜럽(D'LUV)|          0|패션·잡화 딜럽(D'LUV) 딜...|
# |10467|간단한(?) 운동화 매듭묶기 -...|
#     일반인들에겐 간단한(?...|   디자인소품|                아이탑|          0|디자인소품 아이탑 아이탑
#   ...|
# +-----+--------------------+--------------------+--------+-------------------+-----------+--------------------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import Tokenizer,HashingTF, Word2Vec
tokenizer = Tokenizer(inputCol='soop', outputCol='keywords')
wordData = tokenizer.transform(res)
word2Vec = Word2Vec(vectorSize=100, minCount=5, inputCol='keywords', outputCol='word_vec', seed=123)
word2VecData = word2Vec.fit(wordData)
word2VecData = word2VecData.transform(wordData)

# %%
all_wadiz_vecs = word2VecData.select('id','word_vec').rdd.map(lambda x: (x[0], x[1])).collect()

# %%
all_wadiz_vecs[1]
# Out:
# (10047,
#  DenseVector([0.0671, 0.0423, 0.0682, -0.0319, -0.0441, -0.0043, 0.0722, -0.0191, 0.043, 0.0044, 0.0248, -0.0543, -0.0116, -0.0228, -0.0022, 0.014, -0.0083, -0.0015, -0.0254, 0.0159, -0.0684, -0.0394, 0.078, 0.1482, -0.0218, -0.0021, -0.0602, 0.0266, 0.0263, -0.0261, 0.1046, -0.018, 0.0044, -0.0966, 0.0291, 0.1105, 0.0389, -0.0049, 0.0571, -0.0619, -0.0771, 0.0615, 0.0355, 0.0546, -0.0024, 0.0564, -0.0859, -0.0697, -0.0146, -0.0142, 0.0062, 0.0423, -0.0817, -0.0037, 0.1208, 0.0224, 0.0032, 0.0148, 0.1109, 0.0224, 0.007, 0.0646, -0.0861, 0.0254, 0.0006, 0.0128, -0.0978, 0.0124, -0.0792, -0.0799, 0.0497, 0.0191, -0.0668, 0.0457, -0.0247, 0.0202, 0.108, -0.0493, -0.0358, 0.026, 0.0915, 0.0364, -0.0389, -0.0303, -0.0117, 0.0071, 0.0949, -0.1168, 0.0497, -0.057, 0.0077, -0.0958, -0.0393, 0.0625, 0.0163, -0.0276, 0.1247, -0.0137, -0.0285, -0.0471]))

# %%
def CosineSim(vec1, vec2): 
    return np.dot(vec1, vec2) / np.sqrt(np.dot(vec1, vec1)) / np.sqrt(np.dot(vec2, vec2))

# %%
# input: 상품 id 리스트 > output: 추천 상품 (input_id(입력한 상품 id), id(입력한 상품과 코사인 유사도가 제일 높은 상품 id), score(코사인 유사도 계산)))
def getSimilarProduct(w_ids, sim_product_limit=10):
    schema = StructType([   
                        StructField("id", StringType(), True)
                        ,StructField("score", IntegerType(), True)
                        ,StructField("input_id", StringType(), True)
                        ])
    similar_products_df = spark.createDataFrame([], schema)
    for w_id in w_ids:
        w_id = int(w_id)
        input_vec = []
        for r in all_wadiz_vecs:
            if r[0] == w_id:
                input_vec = [(r[1])][0]
            else:
                continue
            similar_product_rdd = sc.parallelize((i[0], float(CosineSim(input_vec, i[1]))) for i in all_wadiz_vecs)
        
            similar_product_df = spark.createDataFrame(similar_product_rdd)\
                            .withColumnRenamed('_1', 'id')\
                            .withColumnRenamed('_2', 'score')\
                            .orderBy('score', ascending = False)
            similar_product_df = similar_product_df.filter(col("id") != w_id).limit(sim_product_limit)
            similar_product_df = similar_product_df.withColumn('input_id', lit(w_id))
            similar_products_df = similar_products_df \
                                        .union(similar_product_df)
    return similar_products_df

# %%
# input: 추천 상품 (input_id, id, score) > output: inner join (input_id, id, score, name, category, makerName, summary)
def getProductDetails(in_product):
    a = in_product.alias("a")
    b = spark_df.alias("b")
    
    return a.join(b, col("a.id") == col("b.id"), 'inner') \
             .select([col('a.'+xx) for xx in a.columns] + [col('b.name'),col('b.category'),
                                                           col('b.makerName'),col('b.summary')])

# %% [markdown]
# ### Test Recommend

# %%
import numpy as np
from pyspark.sql.functions import *

# 상품 id 리스트
wids = [54968, 53536, 42496, 30763, 34841]

# 상품 추천 및 추천 상품 디테일 
sims = getProductDetails(getSimilarProduct(wids))
sims.select('input_id','id','name','summary','category','makerName','score').toPandas()
# Out:
# /home/hadoop/venv/lib/python3.5/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
#    input_id     id                                      name  \
# 0     34841  36468             봄을 닮은 아카시아 향수 : PE FU [FAIRY]
# 1     53536  36898   쾌적한 잠자리 환경을 위한 똑똑한 생활습관  "굿베딩 라이트 스프레이"
# 2     34841  34175           사랑하는 사람(U)을 위해 준비하는 선택, 유추프라카치아
# 3     30763  11125               세상을 바꾼 이들의 얼굴과 철학을 담은 셀럽팝아트
# 4     53536  37148        스크린 골프! 편하고 저렴하게 집에서 즐기세요 . [펀골프]
# 5     34841  58300                 사랑스러운 내 반려견의 손그림 초상화 주문제작
# 6     54968  58713        [LTE와 가성비만남] 태블릿PC 고민? 레볼루션 G10하나로
# 7     53536  49992          환경을생각하는 밀크티만들기KIT(이제는 집에서 만들수있어)
# 8     53536  43280                         간편하고 편리한! 윌빅종이그릇!
# 9     54968  49818                         3형제의 제주 귀농,  청년감귤
# 10    30763  39022       ★2799%앵콜★ 미세분사 샤워헤드로 피부 클렌징 샤워하세요!!
# 11    54968   9298         [앵콜]음악을 즐기는 새로운 방법 : Cork Speaker
# 12    42496  37245   미세먼지 많은 날도 자전거를! 공기청정기 백팩, 더스트닷 [DUST.]
# 13    34841  64522  얼굴만 닦지 말고 눈꺼풀도 세수해주세요! 참 순한 눈 세정제, 헬로아이즈
# 14    53536  48761       흐르는 물에 바로 씻어먹는 신개념 쌀! 밥아저씨 햅쌀 정기 배송
# 15    54968  56871   [ 드드드 ] 선남선녀 머리 감을 때, '드드드' 음파 진동 해보세요!
# 16    34841  38709                       6억신화 여름철 탄 피부를 하얗게!
# 17    54968  45924                      마블 어벤져스 프리미엄 고속충전 패드
# 18    34841  31001                   빅데이터로 보는 미국주식 투자지도 2021
# 19    42496  26050  LED 근적외선을 손목패드에? 나도 이제 손목 스트레스 탈출![땅콩패드]
# 20    30763  50540      부모님께 나의 마음을 전하는 단 한 가지 방법, 올리사랑 다이어리
# 21    42496  28486           [공부 꿀팁] 학습관리 스마트펜, NUBO Rosetta
# 22    30763  15946                    오롯이 책을 읽을 자유 / 공예가 북커버
# 23    53536  52121       [시원,후끈함의 끝판왕]  LED 자석볼 진동마사지기 "몬스겔"
# 24    34841  24895                매일 아침 상처받는 남자들을 위한 쉐이빙 혁명템
# 25    42496  56810       시대를 앞서가는 환기솔루션- Ai 환기청정기 웨이븐(WAVEN)
# 26    54968  60069       [거품 우오옷~!!] 크림맥주거품기 목넘김이 부드러운 "비어링"
# 27    54968  49243        [환경부 1등급 인증] '에이오'로 9가지 공기정보를 동시에!
# 28    34841  40662         세수만으로 팩한 효과를 <마스크팩 1분도 못하는 분들 주목>
# 29    53536  54638                           신년에는 당연히 낙곱새해야죠
# 30    54968  46727  [초강력 자석 초고속 무선충전] 차에서 1초면 충전!! 10종구성 홀그릭
# 31    54968  30111       오늘도 충전 잘 하셨나요? 처음 만나는 무선충전기 [레트로덕Q]
# 32    53536  39535                     세상에 이런 감성낙곱새가 있을 일이야?
# 33    34841  35442  더운 여름! 지치고 늘어진 피부를 즉각적으로 조여주는 -5도 워터리 셔벳
# 34    54968  54796         분유타기 7초 자동완성! 베이비 브레짜 신형 국내 공식 출시
# 35    30763  17858             [한정앵콜] 오롯이 책을 읽을 자유 / 공예가 북커버
# 36    30763  35706  캠핑 입문자 강추! 나무 없어도 OK, 실내외 모두 설치되는 스탠딩 해먹
# 37    30763  11460        책장에서 바로 찾는 노트와 제본 책, 링노트 네임텍 - 엣지텍
# 38    42496  59899        무선충전에 조리기능까지?! 스마트한 우드슬랩. 팔로산토 테이블
# 39    42496  67255  [앵콜] 건조+스팀+수평+수직 All In One 스탠드형 스팀다리미
# 40    30763  36101                        멀티 기능의 5 IN 1 연필꽂이
# 41    53536  41462  [칼로리라이스] 한끼에 58Kcal, 컬리플라워로 만든 저탄수화물 볶음밥
# 42    34841  47289    크릴오일 먹지말고 피부에 양보하세요_비타민C의 6,000배 아스타잔틴
# 43    30763  31022        유화, 손으로 관람하세요! UNIVERSE PHONE CASE
# 44    42496  42725                 iPhone "생폰"의 터치감 그대로, GR4
# 45    30763  17770                 건국 100주년 기념, 무궁화 역사 폰케이스
# 46    42496  35209             자동차 통풍시트에서 찬바람이 나온다면 믿으시겠습니까?
# 47    53536  41107               세상에 꼭 필요했던! [반려동물 초경량 구스패딩]
# 48    42496  53978   "선을 넘는 무선 라이프" [독일 가이타이너 초강력 무선 스팀 다리미]
# 49    42496  52070  [음식물쓰레기냉장고] 부패,악취,해충문제 끝! 세워지는 뚜껑 디테일까지!
#
#                                               summary category  \
# 0   \n    도시의 매연, 자극적인 향수로 지친 후각을 자연의 향으로 힐링하세요.\r...       뷰티
# 1   \n    뷰티를 목적으로 하는 향수가 아닌, 자연을 닮은 향기로 안정감과 편안함을...      홈리빙
# 2   \n    너 이름이 뭐니? 사랑하는 사람을 위해 준비하는 선택, 나의 [유추프라카...       뷰티
# 3   \n    2017년에는 꿈꾸는 이들이 그 꿈을 이룰 수 있도록, 'aboutfra...    디자인소품
# 4   \n    [펀골프] 는 손 쉽게 어디서든 골프를 즐길 수 있는 골프 시뮬레이터입니...    테크·가전
# 5   \n    아름다운 반려견과 반려견을 사랑하는 우리의 마음, 사랑받는 반려견의 행복...     반려동물
# 6   \n    가심비 태블릿의 명가 아이뮤즈가 선보이는 첫번째 LTE 태블릿!\n필압조...    테크·가전
# 7   \n    환경을 생각하는 밀크티만들기KIT 입니다. 환경도 생각하며 집에서도 쉽게...       푸드
# 8   \n    윌빅종이그릇은 사이즈를 축소하여 자유로운 야외활동을 할 수 있습니다. 간...     반려동물
# 9   \n    서울에서 내려온 청년농업인 형제가 일조량이 높은 제주 한경면에서 재배한 ...       푸드
# 10  \n    매일하는 샤워, 샤워헤드가 당신의 샤워 문화를 바꿔줄 수 없을까?\r\n...      홈리빙
# 11  \n    나의 공병이 스피커가 되다. 사용하고 남은 공병들, 버리지 말고 Cork...    테크·가전
# 12  \n    미세먼지 걱정에 마침표를 찍습니다. 밖에서도 항상 '좋음' 수준의 깨끗한...    테크·가전
# 13  \n    오늘도 푸석푸석하고 뿌연 내 시야\n눈을 씻은 것처럼 하루종일 상쾌하고 ...       뷰티
# 14  \n    반찬만큼 중요한 밥!\n밥도 먹을 때마다 맛있게 먹을 수 없을까요?\n밥...       푸드
# 15  \n    음파 진동 브러쉬로 두피를 산뜻하게 케어 하세요! 모발 세척에도 도움이 ...    테크·가전
# 16  \n    6번의 멜라노 관련 제품 펀딩, 약 6억 8천 만원의 펀딩 금액\r\n피...       뷰티
# 17  \n    시장출시전 와디즈 서포터들에게 제품의 대한 가격혜택을 드리고, 마켓테스트...    테크·가전
# 18  \n    제대로 된 정보가 당신의 투자를 새로운 차원의 성공으로 이끕니다. 빅데이...       출판
# 19  \n    요즘 인싸템인 LED마스크와 같은 LED 근적외선 파장을 이용한 손목의!...    테크·가전
# 20  \n    부모님께 서포터님의 진심 어린 마음과 정성을 선물해보시는 게 어떠신가요?...    디자인소품
# 21     \n    영어 단어장, 학습 플래너, 스톱워치를 하나에 담은 펜\n    \n      테크·가전
# 22  \n    오롯이 책을 읽을 수 있도록 도와드릴게요.\r\n공예가 북커버 시리즈.\...    디자인소품
# 23  \n    3종의 LED빛으로 다양한 피부관리를 할 수 있는, 영구자석이 결합된 강...       뷰티
# 24  \n    햄프씨드 오일 외 각종 오일 성분이 피부 보습막을 형성하여 부드러운 면도...       뷰티
# 25  \n    IoT 인공지능으로, 진정한 쾌적함을 유지하는 환기솔루션 웨이븐 !\n ...    테크·가전
# 26  \n    휘릭에서 선보이는 국내 최초 "세척도, 충전도 필요없는" 맥주거품기 비어...    테크·가전
# 27  \n    "지금까지 1등급 인증받은 초미세먼지 측정기는 와디즈에 없었다!" 환경부...    테크·가전
# 28  \n    1일 1팩 하기엔 우리는 너무 바빠요. 세수만으로 팩까지 끝낼 방법이 있...       뷰티
# 29  \n    우리 집 식탁 위에 부산의 감성 그대로 느낄 수 있는 국내산 한우 100...       푸드
# 30  \n    (고속무선충전+자석거치) 4접 마그네틱 방식으로 절대 안 떨어지는 자력,...    테크·가전
# 31  \n    고속 무선충전기, 경험하지 못했다면 레트로덕Q로 시작하세요. 영화 감상하...    테크·가전
# 32  \n    우리 집 식탁 위에 부산의 감성 그대로 느낄 수 있는 국내산 한우 100...       푸드
# 33  \n    [더운 여름 지치고 늘어진 피부를 즉각적으로 조여주는 -5°C 워터리 셔...       뷰티
# 34  \n    전세계 판매 1위에 빛나는 자동 분유제조기 포뮬러 프로 어드밴스드 (Fo...    테크·가전
# 35  \n    오롯이 책을 읽을 수 있도록 도와드릴게요. 공예가 북커버 시리즈.\n  ...    디자인소품
# 36  \n    우리 집에 캠핑하러 올래? 밖으로 나가지 않아도 <루엣비든 해먹스탠드>는...    여행·레저
# 37  \n    스프링 노트 혹은 스프링 제본 책을 책장에 진열해 놓았을 때 어떠한 노트...    디자인소품
# 38  \n    스마트폰 무선충전에 조리기능까지 더한다면?! 스마트하게 업그레이드된 새로...    테크·가전
# 39  \n    기존 다리미의 한계를 뛰어 넘다. \n스팀+건조+수평+수직까지 다 되는 ...    테크·가전
# 40  \n    혁신적인 디자인 5 in 1기능의 연필꽂이, 종이를 세우고, 명함을 꽂고...    디자인소품
# 41  \n    매번 해야하는 손질, 건강만 생각하고 먹었던 컬리플라워는 잊으세요. 컬리...       푸드
# 42  \n    아이부터 성인까지 전성분 EWG 그린 1등급!! 천연 아스타잔틴(비타민C...       뷰티
# 43  \n    여태까지 볼 수 없었던 폰케이스, 당신의 일상에서도 예술을 느껴보세요. ...    디자인소품
# 44  \n    iPhone 생폰의 느낌 그대로- iPhone 스크린의 Gorilla G...    테크·가전
# 45  \n    무궁화를 구별할 수 있나요? 예쁘고 뜻 깊은 무궁화 역사 폰 케이스로 역...    디자인소품
# 46  \n    아이스 냉풍시트는 열전반도체 냉각기술을 이용하여 기존 통풍시트에서 구현하...    테크·가전
# 47  \n    반려동물의 [봄, 가을, 겨울]을 가볍고 따뜻하게 보낼 수 있도록 도와줄...     반려동물
# 48  \n    "자유로운 무선 라이프"\n고성능 전문가용 다리미도 이젠 무선으로 편리하...    테크·가전
# 49  \n    보관하기 괴로운 음식물쓰레기! 대연 '음식물쓰레기 냉장고'는 악취/해충/...    테크·가전
#
#                  makerName     score
# 0                    코이컴퍼니  0.991830
# 1              디노보(DENOVO)  0.986791
# 2     Ucuprakacia(유추프라카치아)  0.992907
# 3               aboutframe  0.995964
# 4                   (주)펀골프  0.984860
# 5                      정유나  0.992129
# 6                    포유디지탈  0.995910
# 7                     오캄앤티  0.988023
# 8                   WilBiC  0.986404
# 9                     청년감귤  0.994108
# 10             (주)아로마센스코리아  1.000000
# 11                  (주)이디연  0.994247
# 12                에어체크업(주)  0.996931
# 13               (주)바이오옵틱스  0.991675
# 14                    밥아저씨  0.982661
# 15                    우리민트  0.995284
# 16                    유리스킨  0.999741
# 17                에스에스트레이드  0.996098
# 18  글로벌 투자 정보의 명가, 도서출판 예문  0.992445
# 19                 엘티프로(주)  0.996433
# 20             가치에 같이를 더하다  0.993899
# 21                 TESOLLO  0.997499
# 22                공예가(OME)  0.992628
# 23                내꺼브랜드LHM  0.982028
# 24                  젠틀프로젝트  0.992899
# 25              (주)에스아이디허브  0.995752
# 26                      휘릭  0.996338
# 27                 (주)이지테크  0.994116
# 28                     비포즈  0.991835
# 29               (주)에이치엔푸드  0.988192
# 30                    메니폭스  0.995193
# 31                WISEKIDS  0.994759
# 32                   감성낙곱새  0.988997
# 33           뷰티핏 BEAUTYFIT  0.992722
# 34                 베이비 브레짜  0.994265
# 35                공예가(OME)  0.993182
# 36                    포레스타  0.993246
# 37                     툭아트  0.994129
# 38                    팔로산토  0.995968
# 39              (주)엠앤에스코리아  0.995909
# 40                     트윈탑  0.992798
# 41              (주)이룸푸드시스템  0.983321
# 42            (주)지티엘커뮤니케이션  0.995344
# 43    13-13 artcyclestudio  0.997195
# 44                아이리스 앤 코  0.997110
# 45                     남달리  0.993807
# 46                  (주)카렉스  0.995961
# 47                     dot  0.982071
# 48              (주)엠앤에스코리아  0.995496
# 49              대연 DAEYEUN  0.996420

# %% [markdown]
# ### User based Recomment

# %%
import csv
import ast
fr = open('users.csv', 'r', encoding='utf-8')
fw = open('users2.csv', 'w', encoding='utf-8')
rdr = csv.reader(fr)
final_list = []
final_list.append(['user_id', 'funding_id'])
for line in rdr:
    funding_list = ast.literal_eval(line[1])
    userid = line[0]
    for fund in funding_list:
      funding_id = fund[0]
      if int(userid) == 0:
          print(funding_id)
      final_list.append([userid, funding_id])
  
wtr = csv.writer(fw)
for row in final_list:
    wtr.writerow(row)
print(len(final_list))
fr.close()
fw.close()
# Out:
# 457921

# %%
user_df = spark.read.csv(
    'users2.csv', header=True, inferSchema=True
)

# %%
user_df.select('user_id' ,'funding_id').show()
user_df.printSchema()
# Out:
# +--------+----------+
# | user_id|funding_id|
# +--------+----------+
# |21910001|     63340|
# |21910001|     65295|
# |21910001|     66226|
# |21910001|     65394|
# |21910001|     64316|
# |21910001|     64291|
# |21910001|     64491|
# |21910001|     62535|
# |21910001|     46865|
# |21910001|     56162|
# |21910001|     61133|
# |21910001|     58058|
# |21910001|     57001|
# |21910001|     58123|
# |21910001|     55116|
# |21910001|     57895|
# |21910001|     54391|
# |21910001|     58655|
# |21910001|     55940|
# |21910001|     56103|
# +--------+----------+
# only showing top 20 rows
#
# root
#  |-- user_id: integer (nullable = true)
#  |-- funding_id: integer (nullable = true)

# %%
user_rdd = user_df.select('user_id','funding_id').rdd.map(lambda x: (x[0], x[1])).collect()

# %%
def getUserBasedRecoms(u_id):
    funding_ids = []
    for u in user_rdd:
        if u[0] == u_id:
            funding_ids.append(u[1])
    print(funding_ids)
    return funding_ids

# %%
funding_ids = getUserBasedRecoms(41140101)
print(funding_ids)
sims = getProductDetails(getSimilarProduct(funding_ids))
sims.select('input_id','id','name','summary','category','makerName','score').toPandas()
# Out:
# [54968, 53536, 42496, 30763, 34841]
# [54968, 53536, 42496, 30763, 34841]
# /home/hadoop/venv/lib/python3.5/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
#    input_id     id                                      name  \
# 0     34841  36468             봄을 닮은 아카시아 향수 : PE FU [FAIRY]
# 1     53536  36898   쾌적한 잠자리 환경을 위한 똑똑한 생활습관  "굿베딩 라이트 스프레이"
# 2     34841  34175           사랑하는 사람(U)을 위해 준비하는 선택, 유추프라카치아
# 3     30763  11125               세상을 바꾼 이들의 얼굴과 철학을 담은 셀럽팝아트
# 4     53536  37148        스크린 골프! 편하고 저렴하게 집에서 즐기세요 . [펀골프]
# 5     34841  58300                 사랑스러운 내 반려견의 손그림 초상화 주문제작
# 6     54968  58713        [LTE와 가성비만남] 태블릿PC 고민? 레볼루션 G10하나로
# 7     53536  49992          환경을생각하는 밀크티만들기KIT(이제는 집에서 만들수있어)
# 8     53536  43280                         간편하고 편리한! 윌빅종이그릇!
# 9     54968  49818                         3형제의 제주 귀농,  청년감귤
# 10    30763  39022       ★2799%앵콜★ 미세분사 샤워헤드로 피부 클렌징 샤워하세요!!
# 11    54968   9298         [앵콜]음악을 즐기는 새로운 방법 : Cork Speaker
# 12    42496  37245   미세먼지 많은 날도 자전거를! 공기청정기 백팩, 더스트닷 [DUST.]
# 13    34841  64522  얼굴만 닦지 말고 눈꺼풀도 세수해주세요! 참 순한 눈 세정제, 헬로아이즈
# 14    53536  48761       흐르는 물에 바로 씻어먹는 신개념 쌀! 밥아저씨 햅쌀 정기 배송
# 15    54968  56871   [ 드드드 ] 선남선녀 머리 감을 때, '드드드' 음파 진동 해보세요!
# 16    34841  38709                       6억신화 여름철 탄 피부를 하얗게!
# 17    54968  45924                      마블 어벤져스 프리미엄 고속충전 패드
# 18    34841  31001                   빅데이터로 보는 미국주식 투자지도 2021
# 19    42496  26050  LED 근적외선을 손목패드에? 나도 이제 손목 스트레스 탈출![땅콩패드]
# 20    30763  50540      부모님께 나의 마음을 전하는 단 한 가지 방법, 올리사랑 다이어리
# 21    42496  28486           [공부 꿀팁] 학습관리 스마트펜, NUBO Rosetta
# 22    30763  15946                    오롯이 책을 읽을 자유 / 공예가 북커버
# 23    53536  52121       [시원,후끈함의 끝판왕]  LED 자석볼 진동마사지기 "몬스겔"
# 24    34841  24895                매일 아침 상처받는 남자들을 위한 쉐이빙 혁명템
# 25    42496  56810       시대를 앞서가는 환기솔루션- Ai 환기청정기 웨이븐(WAVEN)
# 26    54968  60069       [거품 우오옷~!!] 크림맥주거품기 목넘김이 부드러운 "비어링"
# 27    54968  49243        [환경부 1등급 인증] '에이오'로 9가지 공기정보를 동시에!
# 28    34841  40662         세수만으로 팩한 효과를 <마스크팩 1분도 못하는 분들 주목>
# 29    53536  54638                           신년에는 당연히 낙곱새해야죠
# 30    54968  46727  [초강력 자석 초고속 무선충전] 차에서 1초면 충전!! 10종구성 홀그릭
# 31    54968  30111       오늘도 충전 잘 하셨나요? 처음 만나는 무선충전기 [레트로덕Q]
# 32    53536  39535                     세상에 이런 감성낙곱새가 있을 일이야?
# 33    34841  35442  더운 여름! 지치고 늘어진 피부를 즉각적으로 조여주는 -5도 워터리 셔벳
# 34    54968  54796         분유타기 7초 자동완성! 베이비 브레짜 신형 국내 공식 출시
# 35    30763  17858             [한정앵콜] 오롯이 책을 읽을 자유 / 공예가 북커버
# 36    30763  35706  캠핑 입문자 강추! 나무 없어도 OK, 실내외 모두 설치되는 스탠딩 해먹
# 37    30763  11460        책장에서 바로 찾는 노트와 제본 책, 링노트 네임텍 - 엣지텍
# 38    42496  59899        무선충전에 조리기능까지?! 스마트한 우드슬랩. 팔로산토 테이블
# 39    42496  67255  [앵콜] 건조+스팀+수평+수직 All In One 스탠드형 스팀다리미
# 40    30763  36101                        멀티 기능의 5 IN 1 연필꽂이
# 41    53536  41462  [칼로리라이스] 한끼에 58Kcal, 컬리플라워로 만든 저탄수화물 볶음밥
# 42    34841  47289    크릴오일 먹지말고 피부에 양보하세요_비타민C의 6,000배 아스타잔틴
# 43    30763  31022        유화, 손으로 관람하세요! UNIVERSE PHONE CASE
# 44    42496  42725                 iPhone "생폰"의 터치감 그대로, GR4
# 45    30763  17770                 건국 100주년 기념, 무궁화 역사 폰케이스
# 46    42496  35209             자동차 통풍시트에서 찬바람이 나온다면 믿으시겠습니까?
# 47    53536  41107               세상에 꼭 필요했던! [반려동물 초경량 구스패딩]
# 48    42496  53978   "선을 넘는 무선 라이프" [독일 가이타이너 초강력 무선 스팀 다리미]
# 49    42496  52070  [음식물쓰레기냉장고] 부패,악취,해충문제 끝! 세워지는 뚜껑 디테일까지!
#
#                                               summary category  \
# 0   \n    도시의 매연, 자극적인 향수로 지친 후각을 자연의 향으로 힐링하세요.\r...       뷰티
# 1   \n    뷰티를 목적으로 하는 향수가 아닌, 자연을 닮은 향기로 안정감과 편안함을...      홈리빙
# 2   \n    너 이름이 뭐니? 사랑하는 사람을 위해 준비하는 선택, 나의 [유추프라카...       뷰티
# 3   \n    2017년에는 꿈꾸는 이들이 그 꿈을 이룰 수 있도록, 'aboutfra...    디자인소품
# 4   \n    [펀골프] 는 손 쉽게 어디서든 골프를 즐길 수 있는 골프 시뮬레이터입니...    테크·가전
# 5   \n    아름다운 반려견과 반려견을 사랑하는 우리의 마음, 사랑받는 반려견의 행복...     반려동물
# 6   \n    가심비 태블릿의 명가 아이뮤즈가 선보이는 첫번째 LTE 태블릿!\n필압조...    테크·가전
# 7   \n    환경을 생각하는 밀크티만들기KIT 입니다. 환경도 생각하며 집에서도 쉽게...       푸드
# 8   \n    윌빅종이그릇은 사이즈를 축소하여 자유로운 야외활동을 할 수 있습니다. 간...     반려동물
# 9   \n    서울에서 내려온 청년농업인 형제가 일조량이 높은 제주 한경면에서 재배한 ...       푸드
# 10  \n    매일하는 샤워, 샤워헤드가 당신의 샤워 문화를 바꿔줄 수 없을까?\r\n...      홈리빙
# 11  \n    나의 공병이 스피커가 되다. 사용하고 남은 공병들, 버리지 말고 Cork...    테크·가전
# 12  \n    미세먼지 걱정에 마침표를 찍습니다. 밖에서도 항상 '좋음' 수준의 깨끗한...    테크·가전
# 13  \n    오늘도 푸석푸석하고 뿌연 내 시야\n눈을 씻은 것처럼 하루종일 상쾌하고 ...       뷰티
# 14  \n    반찬만큼 중요한 밥!\n밥도 먹을 때마다 맛있게 먹을 수 없을까요?\n밥...       푸드
# 15  \n    음파 진동 브러쉬로 두피를 산뜻하게 케어 하세요! 모발 세척에도 도움이 ...    테크·가전
# 16  \n    6번의 멜라노 관련 제품 펀딩, 약 6억 8천 만원의 펀딩 금액\r\n피...       뷰티
# 17  \n    시장출시전 와디즈 서포터들에게 제품의 대한 가격혜택을 드리고, 마켓테스트...    테크·가전
# 18  \n    제대로 된 정보가 당신의 투자를 새로운 차원의 성공으로 이끕니다. 빅데이...       출판
# 19  \n    요즘 인싸템인 LED마스크와 같은 LED 근적외선 파장을 이용한 손목의!...    테크·가전
# 20  \n    부모님께 서포터님의 진심 어린 마음과 정성을 선물해보시는 게 어떠신가요?...    디자인소품
# 21     \n    영어 단어장, 학습 플래너, 스톱워치를 하나에 담은 펜\n    \n      테크·가전
# 22  \n    오롯이 책을 읽을 수 있도록 도와드릴게요.\r\n공예가 북커버 시리즈.\...    디자인소품
# 23  \n    3종의 LED빛으로 다양한 피부관리를 할 수 있는, 영구자석이 결합된 강...       뷰티
# 24  \n    햄프씨드 오일 외 각종 오일 성분이 피부 보습막을 형성하여 부드러운 면도...       뷰티
# 25  \n    IoT 인공지능으로, 진정한 쾌적함을 유지하는 환기솔루션 웨이븐 !\n ...    테크·가전
# 26  \n    휘릭에서 선보이는 국내 최초 "세척도, 충전도 필요없는" 맥주거품기 비어...    테크·가전
# 27  \n    "지금까지 1등급 인증받은 초미세먼지 측정기는 와디즈에 없었다!" 환경부...    테크·가전
# 28  \n    1일 1팩 하기엔 우리는 너무 바빠요. 세수만으로 팩까지 끝낼 방법이 있...       뷰티
# 29  \n    우리 집 식탁 위에 부산의 감성 그대로 느낄 수 있는 국내산 한우 100...       푸드
# 30  \n    (고속무선충전+자석거치) 4접 마그네틱 방식으로 절대 안 떨어지는 자력,...    테크·가전
# 31  \n    고속 무선충전기, 경험하지 못했다면 레트로덕Q로 시작하세요. 영화 감상하...    테크·가전
# 32  \n    우리 집 식탁 위에 부산의 감성 그대로 느낄 수 있는 국내산 한우 100...       푸드
# 33  \n    [더운 여름 지치고 늘어진 피부를 즉각적으로 조여주는 -5°C 워터리 셔...       뷰티
# 34  \n    전세계 판매 1위에 빛나는 자동 분유제조기 포뮬러 프로 어드밴스드 (Fo...    테크·가전
# 35  \n    오롯이 책을 읽을 수 있도록 도와드릴게요. 공예가 북커버 시리즈.\n  ...    디자인소품
# 36  \n    우리 집에 캠핑하러 올래? 밖으로 나가지 않아도 <루엣비든 해먹스탠드>는...    여행·레저
# 37  \n    스프링 노트 혹은 스프링 제본 책을 책장에 진열해 놓았을 때 어떠한 노트...    디자인소품
# 38  \n    스마트폰 무선충전에 조리기능까지 더한다면?! 스마트하게 업그레이드된 새로...    테크·가전
# 39  \n    기존 다리미의 한계를 뛰어 넘다. \n스팀+건조+수평+수직까지 다 되는 ...    테크·가전
# 40  \n    혁신적인 디자인 5 in 1기능의 연필꽂이, 종이를 세우고, 명함을 꽂고...    디자인소품
# 41  \n    매번 해야하는 손질, 건강만 생각하고 먹었던 컬리플라워는 잊으세요. 컬리...       푸드
# 42  \n    아이부터 성인까지 전성분 EWG 그린 1등급!! 천연 아스타잔틴(비타민C...       뷰티
# 43  \n    여태까지 볼 수 없었던 폰케이스, 당신의 일상에서도 예술을 느껴보세요. ...    디자인소품
# 44  \n    iPhone 생폰의 느낌 그대로- iPhone 스크린의 Gorilla G...    테크·가전
# 45  \n    무궁화를 구별할 수 있나요? 예쁘고 뜻 깊은 무궁화 역사 폰 케이스로 역...    디자인소품
# 46  \n    아이스 냉풍시트는 열전반도체 냉각기술을 이용하여 기존 통풍시트에서 구현하...    테크·가전
# 47  \n    반려동물의 [봄, 가을, 겨울]을 가볍고 따뜻하게 보낼 수 있도록 도와줄...     반려동물
# 48  \n    "자유로운 무선 라이프"\n고성능 전문가용 다리미도 이젠 무선으로 편리하...    테크·가전
# 49  \n    보관하기 괴로운 음식물쓰레기! 대연 '음식물쓰레기 냉장고'는 악취/해충/...    테크·가전
#
#                  makerName     score
# 0                    코이컴퍼니  0.991830
# 1              디노보(DENOVO)  0.986791
# 2     Ucuprakacia(유추프라카치아)  0.992907
# 3               aboutframe  0.995964
# 4                   (주)펀골프  0.984860
# 5                      정유나  0.992129
# 6                    포유디지탈  0.995910
# 7                     오캄앤티  0.988023
# 8                   WilBiC  0.986404
# 9                     청년감귤  0.994108
# 10             (주)아로마센스코리아  1.000000
# 11                  (주)이디연  0.994247
# 12                에어체크업(주)  0.996931
# 13               (주)바이오옵틱스  0.991675
# 14                    밥아저씨  0.982661
# 15                    우리민트  0.995284
# 16                    유리스킨  0.999741
# 17                에스에스트레이드  0.996098
# 18  글로벌 투자 정보의 명가, 도서출판 예문  0.992445
# 19                 엘티프로(주)  0.996433
# 20             가치에 같이를 더하다  0.993899
# 21                 TESOLLO  0.997499
# 22                공예가(OME)  0.992628
# 23                내꺼브랜드LHM  0.982028
# 24                  젠틀프로젝트  0.992899
# 25              (주)에스아이디허브  0.995752
# 26                      휘릭  0.996338
# 27                 (주)이지테크  0.994116
# 28                     비포즈  0.991835
# 29               (주)에이치엔푸드  0.988192
# 30                    메니폭스  0.995193
# 31                WISEKIDS  0.994759
# 32                   감성낙곱새  0.988997
# 33           뷰티핏 BEAUTYFIT  0.992722
# 34                 베이비 브레짜  0.994265
# 35                공예가(OME)  0.993182
# 36                    포레스타  0.993246
# 37                     툭아트  0.994129
# 38                    팔로산토  0.995968
# 39              (주)엠앤에스코리아  0.995909
# 40                     트윈탑  0.992798
# 41              (주)이룸푸드시스템  0.983321
# 42            (주)지티엘커뮤니케이션  0.995344
# 43    13-13 artcyclestudio  0.997195
# 44                아이리스 앤 코  0.997110
# 45                     남달리  0.993807
# 46                  (주)카렉스  0.995961
# 47                     dot  0.982071
# 48              (주)엠앤에스코리아  0.995496
# 49              대연 DAEYEUN  0.996420
